# %% [markdown]
# ## Why pandas?

# %% [markdown]
# *Beginning of Pandas*

# %%
# df_begin = pd.DataFrame(
#     {
#         "Name": [
#             "Braund, Mr. Owen Harris",
#             "Allen, Mr. William Henry",
#             "Bonnell, Miss. Elizabeth",
#         ],
#         "Age": [22, 35, 58],
#         "Sex": ["male", "male", "female"],
#     }
# )
# print(df_begin)
# print("\n")
# print("Age Data: ",df_begin["Age"])
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female
#
#
# Age Data:  0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %% [markdown]
# ## With CSV

# %%
#Flexibility of Python
#Working with Big Data
#Loading Data into pandas
#pip install pandas
import pandas as pd

#for csv
df = pd.read_csv('pokemon_data.csv')#to read csv file
#print(df)#to read entire data
print(df.head(3))#top 3

#for excel 
#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx.head(3))

#df_txt =pd.read_csv('pokemon_data.txt',delimiter="\t")#\t forward slash
#print(df_txt.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
# ## Reading Data In Pandas

# %%
##Read Headers
#print(df.columns)

#Read each column
#print(df['Name'])
#df.Name
#print(df[['Name','Type 1','HP']])


#Read Each Row
#print(df.head(4))

#Read index 1 row
#print(df.iloc[1])#integer location 1
#print(df.iloc[1:4])

#Read a specific location(R,C)
print(df.iloc[2,1])#second row first col

#with loop
#for index,row in df.iterrows():
   # print(index,row['Name'])
    
df.loc[df['Type 1'] == 'Grass']


#official documentation 
#https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html#min-tut-01-tableoriented
# Out:
# Venusaur
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ## Sorting/Describing Data

# %%
#df.describe()

#df
#df.sort_values('Name',ascending=False)#in descending order
#df.sort_values(['Type 1','HP'],ascending=False)
df.sort_values(['Type 1','HP'],ascending=[1,0])#first one ascending,second one descending
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
# df.head(5)
#Adding new col
#df['Total'] = df['HP']+df['Attack'] +df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
#Jupyte notebook still has data frame in memory even above line is not here but still Total frame


#drop col
#df =df.drop(columns=['Total'])
#df.head(5)

#Adding col new way
#df['Total'] = df.iloc[:,4:10].sum(axis=1)#All row,4 col#axis =1 adding horizontally
#df.head(5)

#Reorder Column
cols = list(df.columns.values)
print(type(cols))
print(type(df.columns.values),df.columns.values)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'> ['#' 'Name' 'Type 1' 'Type 2' 'Speed' 'Generation' 'Legendary' 'Total'
#  'HP' 'Attack' 'Defense' 'Sp. Atk' 'Sp. Def']
#    #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0  1              Bulbasaur  Grass  Poison       65     45           1
# 1  2                Ivysaur  Grass  Poison       80     60           1
# 2  3               Venusaur  Grass  Poison      100     80           1
# 3  3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 4  4             Charmander   Fire     NaN       50     65           1
#
#    Legendary  Total  HP  Attack  Defense  Sp. Atk
# 0      False    318  45      49       49       65
# 1      False    405  60      62       63       80
# 2      False    525  80      82       83      100
# 3      False    625  80     100      123      122
# 4      False    309  39      52       43       60

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

# df.to_csv('modified.txt', index=False, sep='\t')#separater

# %% [markdown]
# ## Filtering Data

# %%
#new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]


#new_df
#new_df.reset_index(drop=True,inplace=True)
new_df

#new_df.to_csv('filtered.csv')

#df.loc[df['Name'].str.contains('Mega')]#only Mega

#df.loc[~df['Name'].str.contains('Mega')]#except Mega

#with regular expression
import re 
#df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]#| ---> or in regex
#df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]#flags=re.I means ignor case

df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]#^ start with and * zero or more
# Out:
#        #                 Name    Type 1    Type 2  Sp. Def  Speed  Generation  \
# 20    16               Pidgey    Normal    Flying       35     56           1
# 21    17            Pidgeotto    Normal    Flying       50     71           1
# 22    18              Pidgeot    Normal    Flying       70    101           1
# 23    18  PidgeotMega Pidgeot    Normal    Flying       80    121           1
# 30    25              Pikachu  Electric       NaN       50     90           1
# 136  127               Pinsir       Bug       NaN       70     85           1
# 137  127    PinsirMega Pinsir       Bug    Flying       90    105           1
# 186  172                Pichu  Electric       NaN       35     60           2
# 219  204               Pineco       Bug       NaN       35     15           2
# 239  221            Piloswine       Ice    Ground       60     50           2
# 438  393               Piplup     Water       NaN       56     40           4
# ...

# %% [markdown]
# ## Conditional Changes

# %%
df.loc[df['Type 1']=='Fire','Generation'] = 'MZ'
#df
#df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

# df

dfs = pd.read_csv('modified.csv')

dfs
# Out:
#        #                   Name   Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0      1              Bulbasaur    Grass  Poison       65     45           1
# 1      2                Ivysaur    Grass  Poison       80     60           1
# 2      3               Venusaur    Grass  Poison      100     80           1
# 3      3  VenusaurMega Venusaur    Grass  Poison      120     80           1
# 4      4             Charmander     Fire     NaN       50     65           1
# ..   ...                    ...      ...     ...      ...    ...         ...
# 795  719                Diancie     Rock   Fairy      150     50           6
# 796  719    DiancieMega Diancie     Rock   Fairy      110    110           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost      130     70           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark      130     80           6
# 799  721              Volcanion     Fire   Water       90     70           6
#
# ...

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')


#df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)#Highest defense

#df.groupby(['Type 1']).mean().sort_values('Attack',ascending=False)#Highest defense

#df.groupby(['Type 1']).sum()
#df.groupby(['Type 1']).count()

df['count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['count']#just count col
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)#with same col name

for df in pd.read_csv('modified.csv', chunksize=5):#5 row df
    #print("Chunk Dataframe: ")
    #print(df)
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
    print(new_df)
# Out:
#        # Name Type 1 Type 2 Sp. Def Speed Generation Legendary Total HP  \
# Fire   1    1    NaN      0       1     1          1         1     1  1
# Grass  4    4    NaN      4       4     4          4         4     4  4
#
#       Attack Defense Sp. Atk
# Fire       1       1       1
# Grass      4       4       4
#        # Name Type 1 Type 2 Sp. Def Speed Generation Legendary Total HP  \
# Fire   1    1    NaN      0       1     1          1         1     1  1
# Grass  4    4    NaN      4       4     4          4         4     4  4
# Fire   4    4    NaN      3       4     4          4         4     4  4
# Water  1    1    NaN      0       1     1          1         1     1  1
#
#       Attack Defense Sp. Atk
# Fire       1       1       1
# Grass      4       4       4
# Fire       4       4       4
# Water      1       1       1
#        # Name Type 1 Type 2 Sp. Def Speed Generation Legendary Total HP  \
# ...
